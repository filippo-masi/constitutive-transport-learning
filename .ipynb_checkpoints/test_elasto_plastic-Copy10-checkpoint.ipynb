# %%
"""Train the hard-thermodynamic operator network on elasto-plasticity with isotropic nonlinear hardening data."""
# ---------------------------------------------------------------------------
# Reproducibility and numerical configuration"""Train the hard-thermodynamic operator network on elasto-plasticity with isotropic nonlinear hardening data."""

import pickle
import matplotlib.pyplot as plt

import numpy as np
import torch
import torch.nn.utils.parametrize as P

from src.helpers import BatchZOHRate, EarlyStopping, get_params
from src.input_convex_neural_nets2 import PICNN
from src.integrate import integrate_training
from src.thermodynamics_transport_net import HardThermodynamicsOpNet


# ---------------------------------------------------------------------------
# Reproducibility and numerical configuration
# ---------------------------------------------------------------------------

np.random.seed(1)
torch.manual_seed(1)

# Restrict PyTorch to a single CPU thread.
torch.set_num_threads(1)
torch.set_num_interop_threads(1)

# Use single precision consistently for the data, network, and integration.
dtype = torch.float32

# Report the training losses every `verbose_frequency` epochs.
verbose_frequency = 10

data_path = "./data/elasto_plastic_hardening/training_data.pkl"
results_path = "./checkpoints/elasto_plastic_hardening2.pt"


# ---------------------------------------------------------------------------
# Load and preprocess the training data
# ---------------------------------------------------------------------------

# The dataset contains the strain and stress trajectories, their values at the
# following time step, and the dimensions of the collection.
with open(data_path, "rb") as file:
    data = pickle.load(file)

(
    strain,
    strain_tdt,
    stress,
    stress_tdt,
    N_snapshots,
    N_protocols,
    dim,
) = data
# The loading protocols are parameterized over the normalized interval [0, 1].
dt = 1 / N_snapshots

# Convert the arrays and time step to the precision used by the model.
if dtype == torch.float32:
    dt = np.float32(dt)
    strain = np.float32(strain)
    strain_tdt = np.float32(strain_tdt)
    stress = np.float32(stress)
elif dtype == torch.float64:
    dt = np.float64(dt)
    strain = np.float64(strain)
    strain_tdt = np.float64(strain_tdt)
    stress = np.float64(stress)

# Approximate the prescribed strain rate by a forward difference.
# strain_rate = (strain_tdt - strain) / dt
strain_rate = np.zeros_like(strain)
for i in range(strain[:,:,0].shape[1]):
    strain_rate[:,i] = np.gradient(strain[:,i,0],dt, edge_order=1)[:,None]
# Compute the fixed normalization parameters used for the strain, strain-rate,
# and stress quantities.
prm_strain = get_params(strain)
prm_strain_rate = get_params(strain_rate)
prm_stress = get_params(stress)


# ---------------------------------------------------------------------------
# Construct the hard-thermodynamic operator network
# ---------------------------------------------------------------------------

# Augment the observable strain with one internal coordinate representing the
# hidden hardening state.
dim_hidden = 1
dim_total = dim + dim_hidden

norm_params = [prm_strain, prm_stress, prm_strain_rate]

# The evolution network returns a flattened square transport operator acting on
# the complete state composed of strain and the internal hardening coordinate.
#
# Format:
# [input dimension, output dimension, hidden-layer widths, activation].
evolution_architecture = [
    dim_total,
    dim_total**2,
    [64, 64, 64, 64],
    "relu",
]

# The partially input-convex network represents the scalar free-energy
# potential as a function of the observable strain and hidden state.
energy_net = PICNN(
    input_x_dim = dim,
    input_y_dim = dim_hidden,
    feature_dim = 32,
    feature_y_dim = 32,
    out_dim = 1,
    num_layers = 3,
    act = "elu",
    act_v = "elu",
    dtype=dtype,
)

# Combine the energy potential and constrained evolution operator into the
# hard-thermodynamic constitutive model.
model = HardThermodynamicsOpNet(
    evolution_architecture,
    energy_net,
    norm_params,
    dim,
    dim_hidden,
    dtype=dtype,
)
model.to(dtype)


# ---------------------------------------------------------------------------
# Configure time integration
# ---------------------------------------------------------------------------

time_grid = torch.arange(0, 1.0, dt)

model.step_size = dt

# Treat the prescribed strain rate as piecewise constant over every integration
# interval using a zero-order hold. BatchZOHRate is registered as part of the model.
model.rate_interp = BatchZOHRate(
    time_grid,
    strain_rate,
    dtype=dtype,
)


# ---------------------------------------------------------------------------
# Prepare tensors and initial-state parameters
# ---------------------------------------------------------------------------

stress_train = torch.from_numpy(stress)
strain_train = torch.from_numpy(strain)

# Use every available loading protocol for training.
id_protocol_train_val = np.arange(strain_train.shape[1])

# Register one normalized initial-strain condition.
model.norm_init_cond = torch.nn.Parameter(
    torch.zeros((1, dim), dtype=dtype),
    requires_grad=True,
)


# ---------------------------------------------------------------------------
# Optimization and early stopping
# ---------------------------------------------------------------------------

optimizer = torch.optim.Adam(model.parameters(), lr=5e-3)
n_epochs = 5_000

# Retain the scalar loss history for later inspection or plotting.
training_loss_hist = []

early_stopping = EarlyStopping(
    patience=2_000,
    delta=1.0e-6,
    verbose=False,
    path=results_path,
)

# Normalize the target stresses once because the normalization parameters remain
# fixed throughout training.
norm_stress_target = model.Normalize(stress_train, prm_stress)


# ---------------------------------------------------------------------------
# Training loop
# ---------------------------------------------------------------------------

# Initialize the hidden hardening coordinate to zero for every loading protocol.
# Using `zeros_like(strain_train[0])` assumes that the observable and hidden
# dimensions are compatible, as they are for this one-dimensional benchmark.
init_svars = torch.zeros_like(strain_train[0])

# Because Python excludes the upper range limit, this performs at most 9,999
# optimization steps.
for epoch in range(1, n_epochs):
    optimizer.zero_grad(set_to_none=True)

    # Reuse constrained parametrizations throughout one trajectory integration.
    with P.cached():
        # Recompute the reference energy gradients using the initial strain
        # snapshot and the current energy-network parameters.
        model.ref_grads = model.reference_grads(strain_train[0])

        # Convert the trainable normalized initial strain to physical units.
        # This value is currently inactive because it is not assigned below.
        init_cond = model.DeNormalize(
            model.norm_init_cond,
            model.prm_strain,
        )

        # Initialize the elastic-strain component to zero for every protocol.
        e_strain0 = torch.zeros_like(
            strain_train[0, id_protocol_train_val]
        )

        # Optional assignments from earlier experiments. While these lines remain
        # commented, every protocol starts from zero elastic strain.
        # e_strain0[:1] = init_cond
        # e_strain0[1:2] = init_cond

        # Form the complete initial state by concatenating the elastic-strain and
        # hidden hardening components along the state dimension.
        initial_pred_stress = model.compute_stress(torch.cat((e_strain0,init_svars),axis=-1))
        initial_conditions = torch.cat((e_strain0,init_svars),axis=-1)

        # Integrate all loading protocols over the prescribed time grid.
        pred_state, pred_stress = integrate_training(
            model,
            initial_conditions,
            time_grid,
            id_protocol_train_val,
        )

    # Evaluate the objective in normalized stress coordinates so that stress
    # components with different magnitudes contribute on comparable scales.
    norm_pred_stress = model.Normalize(pred_stress, prm_stress)
    norm_initial_pred_stress = model.Normalize(
        initial_pred_stress,
        prm_stress,
    )

    # Penalize the stress mismatch at the initial snapshot.
    loss_init = torch.mean(
        (norm_initial_pred_stress - norm_stress_target[0]) ** 2
    )

    # Average the full stress-trajectory error over the loading protocols.
    loss_traj = torch.mean((norm_pred_stress[1:] - norm_stress_target[1:])** 2)
    # Combine the initial-state and trajectory contributions.
    loss = loss_init + loss_traj
    training_loss_value = loss.item()
    training_loss_hist.append(training_loss_value)

    # Update the best checkpoint and interrupt training after the configured
    # number of epochs without sufficient improvement.
    if not np.isnan(training_loss_value):
        early_stopping(training_loss_value, model)

        if early_stopping.early_stop:
            print("Training interrupted because of early stopping.")
            break

    # Differentiate through the complete trajectory and update all active trainable parameters.
    loss.backward()
    optimizer.step()

    if epoch % verbose_frequency == 0:
        print(
            f"epoch: {epoch}/{n_epochs}"
            f" | loss: {training_loss_value:.4e}"
            f" | initial cond: {loss_init.item():.4e}"
            f" | stress hist: {loss_traj.item():.4e}"
        )
#
    if epoch % 100 == 0:
        fig, ax = plt.subplots(1, 2, dpi=150, figsize=(5, 1.25))
        for i, protocol in enumerate(id_protocol_train_val):
            ax[0].plot(strain_train[:, protocol].detach().numpy(),
                    stress_train[:, protocol].detach().numpy(),
                    linewidth=3, alpha=0.2, color='black')
            ax[0].plot(strain_train[:,protocol].detach().numpy(),
                    pred_stress[:, protocol].detach().numpy(),
                    linewidth=1, color='black')
            ax[1].plot(strain_train[:,protocol].detach().numpy(),
                    pred_state[:, protocol,-1].detach().numpy(),
                    linewidth=1, color='black')
        ax[0].set_ylabel(r'$q$ (Pa)')  # Stress variable label
        ax[0].set_xlabel(r'$\varepsilon_s$ (-)')  # Strain variable label    
        ax[1].set_ylabel(r'$q$ (Pa)')  # Stress variable label
        ax[1].set_xlabel(r'$p$ (Pa)')  # Strain variable label   
        plt.show()
# Out:
# epoch: 10/5000 | loss: 1.0929e-01 | initial cond: 1.0355e-14 | stress hist: 1.0929e-01
# epoch: 20/5000 | loss: 3.7585e-02 | initial cond: 6.4721e-16 | stress hist: 3.7585e-02
# epoch: 30/5000 | loss: 2.4093e-02 | initial cond: 1.0355e-14 | stress hist: 2.4093e-02
# epoch: 40/5000 | loss: 1.2838e-02 | initial cond: 1.0355e-14 | stress hist: 1.2838e-02
# epoch: 50/5000 | loss: 8.7471e-03 | initial cond: 0.0000e+00 | stress hist: 8.7471e-03
# epoch: 60/5000 | loss: 6.7231e-03 | initial cond: 1.0355e-14 | stress hist: 6.7231e-03
# epoch: 70/5000 | loss: 5.3775e-03 | initial cond: 1.0355e-14 | stress hist: 5.3775e-03
# epoch: 80/5000 | loss: 4.0581e-03 | initial cond: 2.5888e-15 | stress hist: 4.0581e-03
# epoch: 90/5000 | loss: 3.2524e-03 | initial cond: 6.4721e-14 | stress hist: 3.2524e-03
# epoch: 100/5000 | loss: 2.1886e-03 | initial cond: 0.0000e+00 | stress hist: 2.1886e-03
# epoch: 110/5000 | loss: 1.6184e-03 | initial cond: 9.3198e-14 | stress hist: 1.6184e-03
# epoch: 120/5000 | loss: 1.2888e-03 | initial cond: 0.0000e+00 | stress hist: 1.2888e-03
# epoch: 130/5000 | loss: 1.0213e-03 | initial cond: 0.0000e+00 | stress hist: 1.0213e-03
# epoch: 140/5000 | loss: 1.2022e-03 | initial cond: 2.5888e-15 | stress hist: 1.2022e-03
# epoch: 150/5000 | loss: 6.7047e-04 | initial cond: 2.3299e-14 | stress hist: 6.7047e-04
# epoch: 160/5000 | loss: 6.1438e-04 | initial cond: 1.0355e-14 | stress hist: 6.1438e-04
# epoch: 170/5000 | loss: 5.7480e-04 | initial cond: 0.0000e+00 | stress hist: 5.7480e-04
# epoch: 180/5000 | loss: 4.5442e-04 | initial cond: 2.5888e-15 | stress hist: 4.5442e-04
# epoch: 190/5000 | loss: 5.1213e-04 | initial cond: 2.5888e-15 | stress hist: 5.1213e-04
# epoch: 200/5000 | loss: 3.6264e-04 | initial cond: 1.0355e-14 | stress hist: 3.6264e-04
# epoch: 210/5000 | loss: 3.2881e-04 | initial cond: 0.0000e+00 | stress hist: 3.2881e-04
# epoch: 220/5000 | loss: 1.2241e-03 | initial cond: 1.0355e-14 | stress hist: 1.2241e-03
# epoch: 230/5000 | loss: 3.7448e-04 | initial cond: 0.0000e+00 | stress hist: 3.7448e-04
# epoch: 240/5000 | loss: 3.2307e-04 | initial cond: 1.0355e-14 | stress hist: 3.2307e-04
# epoch: 250/5000 | loss: 2.3194e-04 | initial cond: 2.3299e-14 | stress hist: 2.3194e-04
# epoch: 260/5000 | loss: 2.1225e-04 | initial cond: 2.5888e-15 | stress hist: 2.1225e-04
# epoch: 270/5000 | loss: 8.9829e-04 | initial cond: 2.5888e-15 | stress hist: 8.9829e-04
# epoch: 280/5000 | loss: 4.0102e-04 | initial cond: 1.0355e-14 | stress hist: 4.0102e-04
# epoch: 290/5000 | loss: 2.5006e-04 | initial cond: 2.5888e-15 | stress hist: 2.5006e-04
# epoch: 300/5000 | loss: 1.9041e-04 | initial cond: 1.0355e-14 | stress hist: 1.9041e-04
# epoch: 310/5000 | loss: 1.7682e-04 | initial cond: 0.0000e+00 | stress hist: 1.7682e-04
# epoch: 320/5000 | loss: 1.9811e-04 | initial cond: 2.5888e-15 | stress hist: 1.9811e-04
# epoch: 330/5000 | loss: 1.7842e-04 | initial cond: 2.3299e-14 | stress hist: 1.7842e-04
# epoch: 340/5000 | loss: 1.4966e-04 | initial cond: 2.5888e-15 | stress hist: 1.4966e-04
# epoch: 350/5000 | loss: 3.6346e-03 | initial cond: 4.1421e-14 | stress hist: 3.6346e-03
# epoch: 360/5000 | loss: 8.9122e-04 | initial cond: 1.0355e-14 | stress hist: 8.9122e-04
# epoch: 370/5000 | loss: 4.3210e-04 | initial cond: 2.5888e-15 | stress hist: 4.3210e-04
# epoch: 380/5000 | loss: 2.3483e-04 | initial cond: 1.0355e-14 | stress hist: 2.3483e-04
# epoch: 390/5000 | loss: 1.5916e-04 | initial cond: 0.0000e+00 | stress hist: 1.5916e-04
# epoch: 400/5000 | loss: 1.3682e-04 | initial cond: 2.5888e-15 | stress hist: 1.3682e-04
# epoch: 410/5000 | loss: 1.2644e-04 | initial cond: 2.5888e-15 | stress hist: 1.2644e-04
# epoch: 420/5000 | loss: 1.1900e-04 | initial cond: 4.1421e-14 | stress hist: 1.1900e-04
# epoch: 430/5000 | loss: 1.1242e-04 | initial cond: 1.0355e-14 | stress hist: 1.1242e-04
# epoch: 440/5000 | loss: 1.0714e-04 | initial cond: 6.4721e-14 | stress hist: 1.0714e-04
# epoch: 450/5000 | loss: 1.0244e-04 | initial cond: 6.4721e-14 | stress hist: 1.0244e-04
# epoch: 460/5000 | loss: 1.5549e-04 | initial cond: 4.1421e-14 | stress hist: 1.5549e-04
# epoch: 470/5000 | loss: 9.6292e-05 | initial cond: 2.5888e-15 | stress hist: 9.6292e-05
# epoch: 480/5000 | loss: 9.3791e-05 | initial cond: 1.0355e-14 | stress hist: 9.3791e-05
# epoch: 490/5000 | loss: 1.9305e-04 | initial cond: 1.0355e-14 | stress hist: 1.9305e-04
# epoch: 500/5000 | loss: 9.7441e-05 | initial cond: 4.1421e-14 | stress hist: 9.7441e-05
# epoch: 510/5000 | loss: 1.9165e-04 | initial cond: 2.5888e-15 | stress hist: 1.9165e-04
# epoch: 520/5000 | loss: 1.3968e-04 | initial cond: 0.0000e+00 | stress hist: 1.3968e-04
# epoch: 530/5000 | loss: 1.2621e-04 | initial cond: 0.0000e+00 | stress hist: 1.2621e-04
# epoch: 540/5000 | loss: 8.1803e-05 | initial cond: 2.5888e-15 | stress hist: 8.1803e-05
# epoch: 550/5000 | loss: 8.1549e-05 | initial cond: 2.5888e-15 | stress hist: 8.1549e-05
# epoch: 560/5000 | loss: 7.5215e-05 | initial cond: 0.0000e+00 | stress hist: 7.5215e-05
# epoch: 570/5000 | loss: 5.8548e-04 | initial cond: 2.3299e-14 | stress hist: 5.8548e-04
# epoch: 580/5000 | loss: 1.9628e-04 | initial cond: 0.0000e+00 | stress hist: 1.9628e-04
# epoch: 590/5000 | loss: 2.0711e-04 | initial cond: 2.3299e-14 | stress hist: 2.0711e-04
# epoch: 600/5000 | loss: 7.7963e-05 | initial cond: 1.0355e-14 | stress hist: 7.7963e-05
# epoch: 610/5000 | loss: 1.0309e-04 | initial cond: 2.5888e-15 | stress hist: 1.0309e-04
# epoch: 620/5000 | loss: 8.3808e-05 | initial cond: 1.0355e-14 | stress hist: 8.3808e-05
# epoch: 630/5000 | loss: 3.6660e-04 | initial cond: 1.0355e-14 | stress hist: 3.6660e-04
# epoch: 640/5000 | loss: 1.7407e-04 | initial cond: 2.3299e-14 | stress hist: 1.7407e-04
# epoch: 650/5000 | loss: 1.0816e-04 | initial cond: 1.0355e-14 | stress hist: 1.0816e-04
# epoch: 660/5000 | loss: 6.3915e-05 | initial cond: 0.0000e+00 | stress hist: 6.3915e-05
# epoch: 670/5000 | loss: 5.9718e-05 | initial cond: 2.5888e-15 | stress hist: 5.9718e-05
# epoch: 680/5000 | loss: 8.4014e-05 | initial cond: 2.5888e-15 | stress hist: 8.4014e-05
# epoch: 690/5000 | loss: 5.8785e-05 | initial cond: 1.0355e-14 | stress hist: 5.8785e-05
# epoch: 700/5000 | loss: 6.2396e-04 | initial cond: 0.0000e+00 | stress hist: 6.2396e-04
# epoch: 710/5000 | loss: 2.2684e-04 | initial cond: 0.0000e+00 | stress hist: 2.2684e-04
# epoch: 720/5000 | loss: 2.0030e-04 | initial cond: 0.0000e+00 | stress hist: 2.0030e-04
# epoch: 730/5000 | loss: 1.4255e-04 | initial cond: 2.5888e-15 | stress hist: 1.4255e-04
# epoch: 740/5000 | loss: 9.3768e-05 | initial cond: 2.5888e-15 | stress hist: 9.3768e-05
# epoch: 750/5000 | loss: 5.1292e-05 | initial cond: 2.3299e-14 | stress hist: 5.1292e-05
# epoch: 760/5000 | loss: 5.1020e-05 | initial cond: 2.3299e-14 | stress hist: 5.1020e-05
# epoch: 770/5000 | loss: 1.3181e-03 | initial cond: 2.3299e-14 | stress hist: 1.3181e-03
# epoch: 780/5000 | loss: 4.7113e-04 | initial cond: 4.1421e-14 | stress hist: 4.7113e-04
# epoch: 790/5000 | loss: 8.4191e-05 | initial cond: 1.0355e-14 | stress hist: 8.4191e-05
# epoch: 800/5000 | loss: 5.6270e-05 | initial cond: 2.3299e-14 | stress hist: 5.6270e-05
# epoch: 810/5000 | loss: 5.0450e-05 | initial cond: 2.3299e-14 | stress hist: 5.0450e-05
# epoch: 820/5000 | loss: 4.8504e-05 | initial cond: 1.0355e-14 | stress hist: 4.8504e-05
# epoch: 830/5000 | loss: 6.6748e-05 | initial cond: 2.3299e-14 | stress hist: 6.6748e-05
# epoch: 840/5000 | loss: 4.8825e-05 | initial cond: 2.3299e-14 | stress hist: 4.8825e-05
# epoch: 850/5000 | loss: 3.8330e-04 | initial cond: 1.0355e-14 | stress hist: 3.8330e-04
# epoch: 860/5000 | loss: 5.1786e-05 | initial cond: 2.3299e-14 | stress hist: 5.1786e-05
# epoch: 870/5000 | loss: 5.4945e-05 | initial cond: 2.3299e-14 | stress hist: 5.4945e-05
# epoch: 880/5000 | loss: 7.0343e-05 | initial cond: 0.0000e+00 | stress hist: 7.0343e-05
# epoch: 890/5000 | loss: 4.9974e-05 | initial cond: 1.0355e-14 | stress hist: 4.9974e-05
# epoch: 900/5000 | loss: 1.0987e-04 | initial cond: 0.0000e+00 | stress hist: 1.0987e-04
# epoch: 910/5000 | loss: 1.0465e-04 | initial cond: 0.0000e+00 | stress hist: 1.0465e-04
# epoch: 920/5000 | loss: 4.4698e-05 | initial cond: 2.3299e-14 | stress hist: 4.4698e-05
# epoch: 930/5000 | loss: 5.0748e-04 | initial cond: 2.3299e-14 | stress hist: 5.0748e-04
# epoch: 940/5000 | loss: 2.3443e-04 | initial cond: 2.3299e-14 | stress hist: 2.3443e-04
# epoch: 950/5000 | loss: 2.0418e-04 | initial cond: 2.3299e-14 | stress hist: 2.0418e-04
# epoch: 960/5000 | loss: 7.2012e-05 | initial cond: 2.5888e-15 | stress hist: 7.2012e-05
# epoch: 970/5000 | loss: 5.0709e-05 | initial cond: 0.0000e+00 | stress hist: 5.0709e-05
# epoch: 980/5000 | loss: 5.2248e-05 | initial cond: 0.0000e+00 | stress hist: 5.2248e-05
# epoch: 990/5000 | loss: 4.3685e-05 | initial cond: 1.0355e-14 | stress hist: 4.3685e-05
# epoch: 1000/5000 | loss: 3.9632e-05 | initial cond: 0.0000e+00 | stress hist: 3.9632e-05
# epoch: 1010/5000 | loss: 4.3108e-05 | initial cond: 4.1421e-14 | stress hist: 4.3108e-05
# epoch: 1020/5000 | loss: 7.1002e-04 | initial cond: 2.5888e-15 | stress hist: 7.1002e-04
# epoch: 1030/5000 | loss: 3.9540e-04 | initial cond: 1.0355e-14 | stress hist: 3.9540e-04
# epoch: 1040/5000 | loss: 2.7548e-04 | initial cond: 1.0355e-14 | stress hist: 2.7548e-04
# epoch: 1050/5000 | loss: 4.2009e-05 | initial cond: 0.0000e+00 | stress hist: 4.2009e-05
# epoch: 1060/5000 | loss: 7.8579e-05 | initial cond: 1.0355e-14 | stress hist: 7.8579e-05
# epoch: 1070/5000 | loss: 3.7207e-05 | initial cond: 0.0000e+00 | stress hist: 3.7207e-05
# epoch: 1080/5000 | loss: 3.6490e-05 | initial cond: 2.5888e-15 | stress hist: 3.6490e-05
# epoch: 1090/5000 | loss: 3.4381e-05 | initial cond: 0.0000e+00 | stress hist: 3.4381e-05
# epoch: 1100/5000 | loss: 3.6860e-05 | initial cond: 2.5888e-15 | stress hist: 3.6860e-05
# epoch: 1110/5000 | loss: 3.1912e-04 | initial cond: 0.0000e+00 | stress hist: 3.1912e-04
# epoch: 1120/5000 | loss: 2.3719e-04 | initial cond: 4.1421e-14 | stress hist: 2.3719e-04
# epoch: 1130/5000 | loss: 4.9963e-05 | initial cond: 1.0355e-14 | stress hist: 4.9963e-05
# epoch: 1140/5000 | loss: 4.4266e-05 | initial cond: 2.5888e-15 | stress hist: 4.4266e-05
# epoch: 1150/5000 | loss: 6.0610e-05 | initial cond: 1.0355e-14 | stress hist: 6.0610e-05
# epoch: 1160/5000 | loss: 3.4030e-05 | initial cond: 1.0355e-14 | stress hist: 3.4030e-05
# epoch: 1170/5000 | loss: 5.2856e-05 | initial cond: 2.3299e-14 | stress hist: 5.2856e-05
# epoch: 1180/5000 | loss: 5.7747e-04 | initial cond: 1.0355e-14 | stress hist: 5.7747e-04
# epoch: 1190/5000 | loss: 8.3431e-04 | initial cond: 0.0000e+00 | stress hist: 8.3431e-04
# epoch: 1200/5000 | loss: 5.2360e-05 | initial cond: 2.3299e-14 | stress hist: 5.2360e-05
# epoch: 1210/5000 | loss: 1.7797e-04 | initial cond: 2.3299e-14 | stress hist: 1.7797e-04
# epoch: 1220/5000 | loss: 1.0744e-04 | initial cond: 0.0000e+00 | stress hist: 1.0744e-04
# epoch: 1230/5000 | loss: 4.9089e-05 | initial cond: 1.0355e-14 | stress hist: 4.9089e-05
# epoch: 1240/5000 | loss: 3.1697e-05 | initial cond: 1.0355e-14 | stress hist: 3.1697e-05
# epoch: 1250/5000 | loss: 3.4015e-05 | initial cond: 0.0000e+00 | stress hist: 3.4015e-05
# epoch: 1260/5000 | loss: 3.0115e-05 | initial cond: 2.3299e-14 | stress hist: 3.0115e-05
# epoch: 1270/5000 | loss: 3.2037e-05 | initial cond: 1.0355e-14 | stress hist: 3.2037e-05
# epoch: 1280/5000 | loss: 3.6102e-05 | initial cond: 2.5888e-15 | stress hist: 3.6102e-05
# epoch: 1290/5000 | loss: 5.1213e-05 | initial cond: 2.5888e-15 | stress hist: 5.1213e-05
# epoch: 1300/5000 | loss: 1.6327e-04 | initial cond: 0.0000e+00 | stress hist: 1.6327e-04
# epoch: 1310/5000 | loss: 8.0271e-04 | initial cond: 2.3299e-14 | stress hist: 8.0271e-04
# epoch: 1320/5000 | loss: 2.6599e-04 | initial cond: 0.0000e+00 | stress hist: 2.6599e-04
# epoch: 1330/5000 | loss: 4.6035e-05 | initial cond: 1.0355e-14 | stress hist: 4.6035e-05
# epoch: 1340/5000 | loss: 4.6124e-05 | initial cond: 1.0355e-14 | stress hist: 4.6124e-05
# epoch: 1350/5000 | loss: 5.6717e-05 | initial cond: 4.1421e-14 | stress hist: 5.6717e-05
# epoch: 1360/5000 | loss: 3.7681e-05 | initial cond: 2.5888e-15 | stress hist: 3.7681e-05
# epoch: 1370/5000 | loss: 2.8846e-05 | initial cond: 2.5888e-15 | stress hist: 2.8846e-05
# epoch: 1380/5000 | loss: 4.7432e-05 | initial cond: 0.0000e+00 | stress hist: 4.7432e-05
# epoch: 1390/5000 | loss: 1.1152e-03 | initial cond: 0.0000e+00 | stress hist: 1.1152e-03
# epoch: 1400/5000 | loss: 1.0957e-03 | initial cond: 0.0000e+00 | stress hist: 1.0957e-03
# epoch: 1410/5000 | loss: 7.1480e-05 | initial cond: 1.0355e-14 | stress hist: 7.1480e-05
# epoch: 1420/5000 | loss: 4.6585e-05 | initial cond: 0.0000e+00 | stress hist: 4.6585e-05
# epoch: 1430/5000 | loss: 4.0675e-05 | initial cond: 0.0000e+00 | stress hist: 4.0675e-05
# epoch: 1440/5000 | loss: 3.4397e-05 | initial cond: 2.5888e-15 | stress hist: 3.4397e-05
# epoch: 1450/5000 | loss: 2.6814e-05 | initial cond: 0.0000e+00 | stress hist: 2.6814e-05
# epoch: 1460/5000 | loss: 2.7742e-05 | initial cond: 2.5888e-15 | stress hist: 2.7742e-05
# epoch: 1470/5000 | loss: 2.7118e-05 | initial cond: 1.0355e-14 | stress hist: 2.7118e-05
# epoch: 1480/5000 | loss: 2.5149e-05 | initial cond: 2.3299e-14 | stress hist: 2.5149e-05
# epoch: 1490/5000 | loss: 2.5876e-05 | initial cond: 0.0000e+00 | stress hist: 2.5876e-05
# epoch: 1500/5000 | loss: 2.2661e-04 | initial cond: 0.0000e+00 | stress hist: 2.2661e-04
# epoch: 1510/5000 | loss: 8.6018e-05 | initial cond: 2.5888e-15 | stress hist: 8.6018e-05
# epoch: 1520/5000 | loss: 2.8915e-04 | initial cond: 1.0355e-14 | stress hist: 2.8915e-04
# epoch: 1530/5000 | loss: 5.3341e-05 | initial cond: 2.5888e-15 | stress hist: 5.3341e-05
# epoch: 1540/5000 | loss: 4.0585e-05 | initial cond: 1.0355e-14 | stress hist: 4.0585e-05
# epoch: 1550/5000 | loss: 3.6370e-05 | initial cond: 2.5888e-15 | stress hist: 3.6370e-05
# epoch: 1560/5000 | loss: 2.8277e-05 | initial cond: 0.0000e+00 | stress hist: 2.8277e-05
# epoch: 1570/5000 | loss: 2.3823e-05 | initial cond: 1.0355e-14 | stress hist: 2.3823e-05
# epoch: 1580/5000 | loss: 2.3238e-05 | initial cond: 2.5888e-15 | stress hist: 2.3238e-05
# epoch: 1590/5000 | loss: 2.2611e-05 | initial cond: 2.5888e-15 | stress hist: 2.2611e-05
# epoch: 1600/5000 | loss: 2.2946e-05 | initial cond: 2.5888e-15 | stress hist: 2.2946e-05
# epoch: 1610/5000 | loss: 2.3600e-05 | initial cond: 2.5888e-15 | stress hist: 2.3600e-05
# epoch: 1620/5000 | loss: 5.8284e-05 | initial cond: 0.0000e+00 | stress hist: 5.8284e-05
# epoch: 1630/5000 | loss: 5.1961e-04 | initial cond: 0.0000e+00 | stress hist: 5.1961e-04
# epoch: 1640/5000 | loss: 8.5552e-05 | initial cond: 1.0355e-14 | stress hist: 8.5552e-05
# epoch: 1650/5000 | loss: 6.7288e-05 | initial cond: 0.0000e+00 | stress hist: 6.7288e-05
# epoch: 1660/5000 | loss: 6.6014e-05 | initial cond: 2.3299e-14 | stress hist: 6.6014e-05
# epoch: 1670/5000 | loss: 2.3612e-05 | initial cond: 5.8249e-15 | stress hist: 2.3612e-05
# epoch: 1680/5000 | loss: 2.4610e-05 | initial cond: 0.0000e+00 | stress hist: 2.4610e-05
# epoch: 1690/5000 | loss: 2.1662e-05 | initial cond: 2.5888e-15 | stress hist: 2.1662e-05
# epoch: 1700/5000 | loss: 5.6174e-05 | initial cond: 1.6180e-14 | stress hist: 5.6174e-05
# epoch: 1710/5000 | loss: 1.0286e-03 | initial cond: 0.0000e+00 | stress hist: 1.0286e-03
# epoch: 1720/5000 | loss: 3.8269e-04 | initial cond: 1.6180e-14 | stress hist: 3.8269e-04
# epoch: 1730/5000 | loss: 5.5268e-05 | initial cond: 2.5888e-15 | stress hist: 5.5268e-05
# epoch: 1740/5000 | loss: 1.4589e-04 | initial cond: 2.5888e-15 | stress hist: 1.4589e-04
# epoch: 1750/5000 | loss: 4.7447e-05 | initial cond: 2.3299e-14 | stress hist: 4.7447e-05
# epoch: 1760/5000 | loss: 3.3791e-05 | initial cond: 5.8249e-15 | stress hist: 3.3791e-05
# epoch: 1770/5000 | loss: 2.5618e-05 | initial cond: 5.8249e-15 | stress hist: 2.5618e-05
# epoch: 1780/5000 | loss: 2.2628e-05 | initial cond: 1.6180e-14 | stress hist: 2.2628e-05
# epoch: 1790/5000 | loss: 2.0547e-05 | initial cond: 2.5888e-15 | stress hist: 2.0547e-05
# epoch: 1800/5000 | loss: 2.0156e-05 | initial cond: 0.0000e+00 | stress hist: 2.0156e-05
# epoch: 1810/5000 | loss: 2.0231e-05 | initial cond: 2.3299e-14 | stress hist: 2.0231e-05
# epoch: 1820/5000 | loss: 1.9635e-05 | initial cond: 2.5888e-15 | stress hist: 1.9635e-05
# epoch: 1830/5000 | loss: 2.0937e-05 | initial cond: 5.8249e-15 | stress hist: 2.0937e-05
# epoch: 1840/5000 | loss: 2.0840e-04 | initial cond: 0.0000e+00 | stress hist: 2.0840e-04
# epoch: 1850/5000 | loss: 2.1713e-04 | initial cond: 1.0355e-14 | stress hist: 2.1713e-04
# epoch: 1860/5000 | loss: 5.4555e-04 | initial cond: 0.0000e+00 | stress hist: 5.4555e-04
# epoch: 1870/5000 | loss: 5.1015e-05 | initial cond: 4.1421e-14 | stress hist: 5.1015e-05
# epoch: 1880/5000 | loss: 8.7494e-05 | initial cond: 4.1421e-14 | stress hist: 8.7494e-05
# epoch: 1890/5000 | loss: 3.5549e-05 | initial cond: 1.0355e-14 | stress hist: 3.5549e-05
# epoch: 1900/5000 | loss: 4.0451e-05 | initial cond: 1.0355e-14 | stress hist: 4.0451e-05
# epoch: 1910/5000 | loss: 2.2152e-05 | initial cond: 0.0000e+00 | stress hist: 2.2152e-05
# epoch: 1920/5000 | loss: 1.9953e-05 | initial cond: 1.0355e-14 | stress hist: 1.9953e-05
# epoch: 1930/5000 | loss: 1.9597e-05 | initial cond: 1.0355e-14 | stress hist: 1.9597e-05
# epoch: 1940/5000 | loss: 1.8772e-05 | initial cond: 1.6180e-14 | stress hist: 1.8772e-05
# epoch: 1950/5000 | loss: 1.8398e-05 | initial cond: 2.5888e-15 | stress hist: 1.8398e-05
# epoch: 1960/5000 | loss: 1.8492e-05 | initial cond: 1.6180e-14 | stress hist: 1.8492e-05
# epoch: 1970/5000 | loss: 4.2108e-05 | initial cond: 5.8249e-15 | stress hist: 4.2108e-05
# epoch: 1980/5000 | loss: 7.0940e-04 | initial cond: 2.3299e-14 | stress hist: 7.0940e-04
# epoch: 1990/5000 | loss: 2.7156e-04 | initial cond: 5.8249e-15 | stress hist: 2.7156e-04
# epoch: 2000/5000 | loss: 2.6883e-04 | initial cond: 0.0000e+00 | stress hist: 2.6883e-04
# epoch: 2010/5000 | loss: 8.7657e-05 | initial cond: 1.6180e-14 | stress hist: 8.7657e-05
# epoch: 2020/5000 | loss: 2.4279e-05 | initial cond: 1.6180e-14 | stress hist: 2.4279e-05
# epoch: 2030/5000 | loss: 2.3051e-05 | initial cond: 0.0000e+00 | stress hist: 2.3051e-05
# epoch: 2040/5000 | loss: 2.0350e-05 | initial cond: 2.5888e-15 | stress hist: 2.0350e-05
# epoch: 2050/5000 | loss: 1.8448e-05 | initial cond: 5.8249e-15 | stress hist: 1.8448e-05
# epoch: 2060/5000 | loss: 1.8303e-05 | initial cond: 0.0000e+00 | stress hist: 1.8303e-05
# epoch: 2070/5000 | loss: 3.5894e-05 | initial cond: 1.6180e-14 | stress hist: 3.5894e-05
# epoch: 2080/5000 | loss: 3.5331e-04 | initial cond: 5.8249e-15 | stress hist: 3.5331e-04
# epoch: 2090/5000 | loss: 7.8376e-04 | initial cond: 5.2424e-14 | stress hist: 7.8376e-04
# epoch: 2100/5000 | loss: 8.5779e-05 | initial cond: 5.8249e-15 | stress hist: 8.5779e-05
# epoch: 2110/5000 | loss: 1.3342e-04 | initial cond: 6.4721e-16 | stress hist: 1.3342e-04
# epoch: 2120/5000 | loss: 2.2032e-05 | initial cond: 2.5888e-15 | stress hist: 2.2032e-05
# epoch: 2130/5000 | loss: 3.5459e-05 | initial cond: 3.1713e-14 | stress hist: 3.5459e-05
# epoch: 2140/5000 | loss: 2.4463e-05 | initial cond: 6.4721e-16 | stress hist: 2.4463e-05
# epoch: 2150/5000 | loss: 1.9488e-05 | initial cond: 6.4721e-14 | stress hist: 1.9488e-05
# epoch: 2160/5000 | loss: 1.9310e-05 | initial cond: 2.5888e-15 | stress hist: 1.9310e-05
# epoch: 2170/5000 | loss: 1.8112e-05 | initial cond: 0.0000e+00 | stress hist: 1.8112e-05
# epoch: 2180/5000 | loss: 3.1070e-05 | initial cond: 0.0000e+00 | stress hist: 3.1070e-05
# epoch: 2190/5000 | loss: 5.0440e-05 | initial cond: 0.0000e+00 | stress hist: 5.0440e-05
# epoch: 2200/5000 | loss: 2.1364e-05 | initial cond: 5.8249e-15 | stress hist: 2.1364e-05
# epoch: 2210/5000 | loss: 4.5534e-05 | initial cond: 5.8249e-15 | stress hist: 4.5534e-05
# epoch: 2220/5000 | loss: 1.5172e-04 | initial cond: 6.4721e-16 | stress hist: 1.5172e-04
# epoch: 2230/5000 | loss: 5.1269e-05 | initial cond: 5.8249e-15 | stress hist: 5.1269e-05
# epoch: 2240/5000 | loss: 1.5911e-04 | initial cond: 5.8249e-15 | stress hist: 1.5911e-04
# epoch: 2250/5000 | loss: 9.6432e-05 | initial cond: 6.4721e-16 | stress hist: 9.6432e-05
# epoch: 2260/5000 | loss: 2.1024e-05 | initial cond: 1.0355e-14 | stress hist: 2.1024e-05
# epoch: 2270/5000 | loss: 1.7768e-05 | initial cond: 4.1421e-14 | stress hist: 1.7768e-05
# epoch: 2280/5000 | loss: 1.7965e-05 | initial cond: 4.1421e-14 | stress hist: 1.7965e-05
# epoch: 2290/5000 | loss: 2.0331e-05 | initial cond: 0.0000e+00 | stress hist: 2.0331e-05
# epoch: 2300/5000 | loss: 2.1431e-05 | initial cond: 1.0355e-14 | stress hist: 2.1431e-05
# epoch: 2310/5000 | loss: 1.9089e-05 | initial cond: 2.3299e-14 | stress hist: 1.9089e-05
# epoch: 2320/5000 | loss: 1.5466e-05 | initial cond: 2.5888e-15 | stress hist: 1.5466e-05
# epoch: 2330/5000 | loss: 2.2017e-05 | initial cond: 3.1713e-14 | stress hist: 2.2017e-05
# epoch: 2340/5000 | loss: 4.3879e-03 | initial cond: 1.6180e-14 | stress hist: 4.3879e-03
# epoch: 2350/5000 | loss: 6.6220e-03 | initial cond: 1.6180e-14 | stress hist: 6.6220e-03
# epoch: 2360/5000 | loss: 1.5573e-02 | initial cond: 0.0000e+00 | stress hist: 1.5573e-02
# epoch: 2370/5000 | loss: 5.3003e-03 | initial cond: 1.0355e-14 | stress hist: 5.3003e-03
# epoch: 2380/5000 | loss: 1.2306e-03 | initial cond: 2.5888e-15 | stress hist: 1.2306e-03
# epoch: 2390/5000 | loss: 9.0522e-04 | initial cond: 2.5888e-15 | stress hist: 9.0522e-04
# epoch: 2400/5000 | loss: 4.1419e-04 | initial cond: 2.5888e-15 | stress hist: 4.1419e-04
# epoch: 2410/5000 | loss: 2.9677e-04 | initial cond: 0.0000e+00 | stress hist: 2.9677e-04
# epoch: 2420/5000 | loss: 1.7919e-04 | initial cond: 0.0000e+00 | stress hist: 1.7919e-04
# epoch: 2430/5000 | loss: 1.4481e-04 | initial cond: 2.5888e-15 | stress hist: 1.4481e-04
# epoch: 2440/5000 | loss: 1.1794e-04 | initial cond: 2.5888e-15 | stress hist: 1.1794e-04
# epoch: 2450/5000 | loss: 9.6981e-05 | initial cond: 1.0355e-14 | stress hist: 9.6981e-05
# epoch: 2460/5000 | loss: 8.2974e-05 | initial cond: 0.0000e+00 | stress hist: 8.2974e-05
# epoch: 2470/5000 | loss: 7.3033e-05 | initial cond: 0.0000e+00 | stress hist: 7.3033e-05
# epoch: 2480/5000 | loss: 6.5355e-05 | initial cond: 0.0000e+00 | stress hist: 6.5355e-05
# epoch: 2490/5000 | loss: 5.9721e-05 | initial cond: 2.3299e-14 | stress hist: 5.9721e-05
# epoch: 2500/5000 | loss: 5.5417e-05 | initial cond: 0.0000e+00 | stress hist: 5.5417e-05
# epoch: 2510/5000 | loss: 5.1839e-05 | initial cond: 1.0355e-14 | stress hist: 5.1839e-05
# epoch: 2520/5000 | loss: 4.8873e-05 | initial cond: 2.3299e-14 | stress hist: 4.8873e-05
# epoch: 2530/5000 | loss: 4.6191e-05 | initial cond: 2.3299e-14 | stress hist: 4.6191e-05
# epoch: 2540/5000 | loss: 4.3766e-05 | initial cond: 4.1421e-14 | stress hist: 4.3766e-05
# epoch: 2550/5000 | loss: 4.1726e-05 | initial cond: 0.0000e+00 | stress hist: 4.1726e-05
# epoch: 2560/5000 | loss: 3.9768e-05 | initial cond: 1.0355e-14 | stress hist: 3.9768e-05
# epoch: 2570/5000 | loss: 3.7600e-05 | initial cond: 2.3299e-14 | stress hist: 3.7600e-05
# epoch: 2580/5000 | loss: 3.5444e-05 | initial cond: 6.4721e-14 | stress hist: 3.5444e-05
# epoch: 2590/5000 | loss: 3.4156e-05 | initial cond: 0.0000e+00 | stress hist: 3.4156e-05
# epoch: 2600/5000 | loss: 7.8925e-05 | initial cond: 0.0000e+00 | stress hist: 7.8925e-05
# epoch: 2610/5000 | loss: 3.7893e-05 | initial cond: 0.0000e+00 | stress hist: 3.7893e-05
# epoch: 2620/5000 | loss: 5.9521e-05 | initial cond: 1.0355e-14 | stress hist: 5.9521e-05
# epoch: 2630/5000 | loss: 4.2467e-05 | initial cond: 0.0000e+00 | stress hist: 4.2467e-05
# epoch: 2640/5000 | loss: 4.8974e-05 | initial cond: 4.1421e-14 | stress hist: 4.8974e-05
# epoch: 2650/5000 | loss: 6.1869e-05 | initial cond: 1.0355e-14 | stress hist: 6.1869e-05
# epoch: 2660/5000 | loss: 6.7786e-05 | initial cond: 2.3299e-14 | stress hist: 6.7786e-05
# epoch: 2670/5000 | loss: 5.5413e-05 | initial cond: 6.4721e-14 | stress hist: 5.5413e-05
# epoch: 2680/5000 | loss: 5.2471e-05 | initial cond: 4.1421e-14 | stress hist: 5.2471e-05
# epoch: 2690/5000 | loss: 7.7091e-05 | initial cond: 2.5888e-15 | stress hist: 7.7091e-05
# epoch: 2700/5000 | loss: 5.2678e-05 | initial cond: 2.5888e-15 | stress hist: 5.2678e-05
# epoch: 2710/5000 | loss: 5.5563e-05 | initial cond: 1.0355e-14 | stress hist: 5.5563e-05
# epoch: 2720/5000 | loss: 1.2902e-04 | initial cond: 2.5888e-15 | stress hist: 1.2902e-04
# epoch: 2730/5000 | loss: 3.6422e-05 | initial cond: 2.3299e-14 | stress hist: 3.6422e-05
# epoch: 2740/5000 | loss: 3.1752e-05 | initial cond: 1.0355e-14 | stress hist: 3.1752e-05
# epoch: 2750/5000 | loss: 1.3054e-04 | initial cond: 4.1421e-14 | stress hist: 1.3054e-04
# epoch: 2760/5000 | loss: 5.3134e-05 | initial cond: 6.4721e-14 | stress hist: 5.3134e-05
# epoch: 2770/5000 | loss: 2.6901e-05 | initial cond: 1.0355e-14 | stress hist: 2.6901e-05
# epoch: 2780/5000 | loss: 1.2293e-04 | initial cond: 1.0355e-14 | stress hist: 1.2293e-04
# epoch: 2790/5000 | loss: 8.5229e-05 | initial cond: 1.0355e-14 | stress hist: 8.5229e-05
# epoch: 2800/5000 | loss: 2.3825e-05 | initial cond: 1.0355e-14 | stress hist: 2.3825e-05
# epoch: 2810/5000 | loss: 7.4538e-05 | initial cond: 0.0000e+00 | stress hist: 7.4538e-05
# epoch: 2820/5000 | loss: 4.0687e-04 | initial cond: 1.0355e-14 | stress hist: 4.0687e-04
# epoch: 2830/5000 | loss: 1.4932e-04 | initial cond: 2.3299e-14 | stress hist: 1.4932e-04
# epoch: 2840/5000 | loss: 6.0226e-05 | initial cond: 0.0000e+00 | stress hist: 6.0226e-05
# epoch: 2850/5000 | loss: 3.0961e-05 | initial cond: 2.5888e-15 | stress hist: 3.0961e-05
# epoch: 2860/5000 | loss: 2.8106e-05 | initial cond: 2.5888e-15 | stress hist: 2.8106e-05
# epoch: 2870/5000 | loss: 2.8882e-05 | initial cond: 2.3299e-14 | stress hist: 2.8882e-05
# epoch: 2880/5000 | loss: 3.3776e-05 | initial cond: 1.0355e-14 | stress hist: 3.3776e-05
# epoch: 2890/5000 | loss: 7.1065e-05 | initial cond: 1.0355e-14 | stress hist: 7.1065e-05
# epoch: 2900/5000 | loss: 9.2036e-05 | initial cond: 1.0355e-14 | stress hist: 9.2036e-05
# epoch: 2910/5000 | loss: 4.9011e-05 | initial cond: 2.3299e-14 | stress hist: 4.9011e-05
# epoch: 2920/5000 | loss: 7.9689e-05 | initial cond: 0.0000e+00 | stress hist: 7.9689e-05
# epoch: 2930/5000 | loss: 1.3115e-04 | initial cond: 0.0000e+00 | stress hist: 1.3115e-04
# epoch: 2940/5000 | loss: 3.0791e-05 | initial cond: 1.0355e-14 | stress hist: 3.0791e-05
# epoch: 2950/5000 | loss: 2.7274e-05 | initial cond: 1.0355e-14 | stress hist: 2.7274e-05
# epoch: 2960/5000 | loss: 1.6376e-04 | initial cond: 0.0000e+00 | stress hist: 1.6376e-04
# epoch: 2970/5000 | loss: 8.2213e-04 | initial cond: 0.0000e+00 | stress hist: 8.2213e-04
# epoch: 2980/5000 | loss: 7.9413e-05 | initial cond: 1.0355e-14 | stress hist: 7.9413e-05
# epoch: 2990/5000 | loss: 7.7989e-05 | initial cond: 2.5888e-15 | stress hist: 7.7989e-05
# epoch: 3000/5000 | loss: 2.4773e-05 | initial cond: 0.0000e+00 | stress hist: 2.4773e-05
# epoch: 3010/5000 | loss: 3.2655e-05 | initial cond: 0.0000e+00 | stress hist: 3.2655e-05
# epoch: 3020/5000 | loss: 2.2620e-05 | initial cond: 4.1421e-14 | stress hist: 2.2620e-05
# epoch: 3030/5000 | loss: 2.1162e-05 | initial cond: 0.0000e+00 | stress hist: 2.1162e-05
# epoch: 3040/5000 | loss: 2.3242e-05 | initial cond: 1.0355e-14 | stress hist: 2.3242e-05
# epoch: 3050/5000 | loss: 2.4292e-05 | initial cond: 2.5888e-15 | stress hist: 2.4292e-05
# epoch: 3060/5000 | loss: 4.7244e-05 | initial cond: 0.0000e+00 | stress hist: 4.7244e-05
# epoch: 3070/5000 | loss: 5.7939e-05 | initial cond: 2.5888e-15 | stress hist: 5.7939e-05
# epoch: 3080/5000 | loss: 5.1780e-05 | initial cond: 4.1421e-14 | stress hist: 5.1780e-05
# epoch: 3090/5000 | loss: 8.5497e-05 | initial cond: 4.1421e-14 | stress hist: 8.5497e-05
# epoch: 3100/5000 | loss: 7.8055e-05 | initial cond: 6.4721e-14 | stress hist: 7.8055e-05
# epoch: 3110/5000 | loss: 1.9552e-05 | initial cond: 4.1421e-14 | stress hist: 1.9552e-05
# epoch: 3120/5000 | loss: 4.5249e-05 | initial cond: 4.1421e-14 | stress hist: 4.5249e-05
# epoch: 3130/5000 | loss: 1.5538e-04 | initial cond: 0.0000e+00 | stress hist: 1.5538e-04
# epoch: 3140/5000 | loss: 4.3104e-04 | initial cond: 0.0000e+00 | stress hist: 4.3104e-04
# epoch: 3150/5000 | loss: 1.2870e-04 | initial cond: 0.0000e+00 | stress hist: 1.2870e-04
# epoch: 3160/5000 | loss: 2.2107e-05 | initial cond: 2.5888e-15 | stress hist: 2.2107e-05
# epoch: 3170/5000 | loss: 2.7384e-05 | initial cond: 1.0355e-14 | stress hist: 2.7384e-05
# epoch: 3180/5000 | loss: 2.6034e-05 | initial cond: 2.5888e-15 | stress hist: 2.6034e-05
# epoch: 3190/5000 | loss: 2.1474e-05 | initial cond: 2.5888e-15 | stress hist: 2.1474e-05
# epoch: 3200/5000 | loss: 2.0015e-05 | initial cond: 1.0355e-14 | stress hist: 2.0015e-05
# epoch: 3210/5000 | loss: 3.3568e-05 | initial cond: 1.0355e-14 | stress hist: 3.3568e-05
# epoch: 3220/5000 | loss: 2.0433e-04 | initial cond: 2.5888e-15 | stress hist: 2.0433e-04
# epoch: 3230/5000 | loss: 4.1597e-04 | initial cond: 0.0000e+00 | stress hist: 4.1597e-04
# epoch: 3240/5000 | loss: 9.1655e-05 | initial cond: 0.0000e+00 | stress hist: 9.1655e-05
# epoch: 3250/5000 | loss: 2.1490e-05 | initial cond: 1.0355e-14 | stress hist: 2.1490e-05
# epoch: 3260/5000 | loss: 3.3554e-05 | initial cond: 4.1421e-14 | stress hist: 3.3554e-05
# epoch: 3270/5000 | loss: 2.4953e-05 | initial cond: 2.5888e-15 | stress hist: 2.4953e-05
# epoch: 3280/5000 | loss: 2.0687e-05 | initial cond: 0.0000e+00 | stress hist: 2.0687e-05
# epoch: 3290/5000 | loss: 1.7652e-05 | initial cond: 0.0000e+00 | stress hist: 1.7652e-05
# epoch: 3300/5000 | loss: 4.1709e-05 | initial cond: 1.0355e-14 | stress hist: 4.1709e-05
# epoch: 3310/5000 | loss: 3.5549e-04 | initial cond: 0.0000e+00 | stress hist: 3.5549e-04
# epoch: 3320/5000 | loss: 7.4250e-05 | initial cond: 2.5888e-15 | stress hist: 7.4250e-05
# epoch: 3330/5000 | loss: 4.2585e-05 | initial cond: 2.5888e-15 | stress hist: 4.2585e-05
# epoch: 3340/5000 | loss: 4.1902e-05 | initial cond: 1.0355e-14 | stress hist: 4.1902e-05
# epoch: 3350/5000 | loss: 1.8400e-05 | initial cond: 2.5888e-15 | stress hist: 1.8400e-05
# epoch: 3360/5000 | loss: 1.9977e-05 | initial cond: 1.0355e-14 | stress hist: 1.9977e-05
# epoch: 3370/5000 | loss: 1.8393e-05 | initial cond: 2.5888e-15 | stress hist: 1.8393e-05
# epoch: 3380/5000 | loss: 1.8508e-05 | initial cond: 2.5888e-15 | stress hist: 1.8508e-05
# epoch: 3390/5000 | loss: 1.6906e-05 | initial cond: 2.5888e-15 | stress hist: 1.6906e-05
# epoch: 3400/5000 | loss: 3.0977e-05 | initial cond: 1.0355e-14 | stress hist: 3.0977e-05
# epoch: 3410/5000 | loss: 8.3606e-04 | initial cond: 2.5888e-15 | stress hist: 8.3606e-04
# epoch: 3420/5000 | loss: 5.5449e-04 | initial cond: 0.0000e+00 | stress hist: 5.5449e-04
# epoch: 3430/5000 | loss: 2.2632e-05 | initial cond: 1.0355e-14 | stress hist: 2.2632e-05
# epoch: 3440/5000 | loss: 3.3019e-05 | initial cond: 1.0355e-14 | stress hist: 3.3019e-05
# epoch: 3450/5000 | loss: 2.9459e-05 | initial cond: 2.5888e-15 | stress hist: 2.9459e-05
# epoch: 3460/5000 | loss: 2.5604e-05 | initial cond: 0.0000e+00 | stress hist: 2.5604e-05
# epoch: 3470/5000 | loss: 1.8002e-05 | initial cond: 0.0000e+00 | stress hist: 1.8002e-05
# epoch: 3480/5000 | loss: 1.7915e-05 | initial cond: 2.5888e-15 | stress hist: 1.7915e-05
# epoch: 3490/5000 | loss: 1.6805e-05 | initial cond: 1.0355e-14 | stress hist: 1.6805e-05
# epoch: 3500/5000 | loss: 1.6529e-05 | initial cond: 0.0000e+00 | stress hist: 1.6529e-05
# epoch: 3510/5000 | loss: 1.6198e-05 | initial cond: 2.3299e-14 | stress hist: 1.6198e-05
# epoch: 3520/5000 | loss: 2.7473e-05 | initial cond: 2.3299e-14 | stress hist: 2.7473e-05
# epoch: 3530/5000 | loss: 1.3055e-04 | initial cond: 1.0355e-14 | stress hist: 1.3055e-04
# epoch: 3540/5000 | loss: 2.0754e-05 | initial cond: 0.0000e+00 | stress hist: 2.0754e-05
# epoch: 3550/5000 | loss: 4.0844e-05 | initial cond: 0.0000e+00 | stress hist: 4.0844e-05
# epoch: 3560/5000 | loss: 2.3033e-05 | initial cond: 2.5888e-15 | stress hist: 2.3033e-05
# epoch: 3570/5000 | loss: 2.2059e-05 | initial cond: 0.0000e+00 | stress hist: 2.2059e-05
# epoch: 3580/5000 | loss: 1.9718e-04 | initial cond: 4.1421e-14 | stress hist: 1.9718e-04
# epoch: 3590/5000 | loss: 3.8617e-05 | initial cond: 2.5888e-15 | stress hist: 3.8617e-05
# epoch: 3600/5000 | loss: 1.6693e-04 | initial cond: 1.0355e-14 | stress hist: 1.6693e-04
# epoch: 3610/5000 | loss: 1.9949e-05 | initial cond: 0.0000e+00 | stress hist: 1.9949e-05
# epoch: 3620/5000 | loss: 2.4611e-05 | initial cond: 0.0000e+00 | stress hist: 2.4611e-05
# epoch: 3630/5000 | loss: 2.6897e-05 | initial cond: 1.0355e-14 | stress hist: 2.6897e-05
# epoch: 3640/5000 | loss: 1.6556e-05 | initial cond: 1.0355e-14 | stress hist: 1.6556e-05
# epoch: 3650/5000 | loss: 1.7423e-05 | initial cond: 1.0355e-14 | stress hist: 1.7423e-05
# epoch: 3660/5000 | loss: 1.5874e-05 | initial cond: 1.0355e-14 | stress hist: 1.5874e-05
# epoch: 3670/5000 | loss: 1.5676e-05 | initial cond: 1.0355e-14 | stress hist: 1.5676e-05
# epoch: 3680/5000 | loss: 1.5553e-05 | initial cond: 0.0000e+00 | stress hist: 1.5553e-05
# epoch: 3690/5000 | loss: 2.7027e-05 | initial cond: 2.5888e-15 | stress hist: 2.7027e-05
# epoch: 3700/5000 | loss: 9.1890e-05 | initial cond: 0.0000e+00 | stress hist: 9.1890e-05
# epoch: 3710/5000 | loss: 4.7898e-05 | initial cond: 1.0355e-14 | stress hist: 4.7898e-05
# epoch: 3720/5000 | loss: 3.9360e-05 | initial cond: 0.0000e+00 | stress hist: 3.9360e-05
# epoch: 3730/5000 | loss: 1.4491e-05 | initial cond: 0.0000e+00 | stress hist: 1.4491e-05
# epoch: 3740/5000 | loss: 2.1527e-05 | initial cond: 2.5888e-15 | stress hist: 2.1527e-05
# epoch: 3750/5000 | loss: 5.5686e-04 | initial cond: 0.0000e+00 | stress hist: 5.5686e-04
# epoch: 3760/5000 | loss: 4.6300e-04 | initial cond: 1.0355e-14 | stress hist: 4.6300e-04
# epoch: 3770/5000 | loss: 1.1565e-04 | initial cond: 1.0355e-14 | stress hist: 1.1565e-04
# epoch: 3780/5000 | loss: 6.0940e-05 | initial cond: 0.0000e+00 | stress hist: 6.0940e-05
# epoch: 3790/5000 | loss: 3.6067e-05 | initial cond: 0.0000e+00 | stress hist: 3.6067e-05
# epoch: 3800/5000 | loss: 2.3715e-05 | initial cond: 1.0355e-14 | stress hist: 2.3715e-05
# epoch: 3810/5000 | loss: 1.6169e-05 | initial cond: 2.3299e-14 | stress hist: 1.6169e-05
# epoch: 3820/5000 | loss: 1.6188e-05 | initial cond: 2.5888e-15 | stress hist: 1.6188e-05
# epoch: 3830/5000 | loss: 1.4626e-05 | initial cond: 2.5888e-15 | stress hist: 1.4626e-05
# epoch: 3840/5000 | loss: 1.4295e-05 | initial cond: 2.5888e-15 | stress hist: 1.4295e-05
# epoch: 3850/5000 | loss: 1.3943e-05 | initial cond: 0.0000e+00 | stress hist: 1.3943e-05
# epoch: 3860/5000 | loss: 2.6477e-05 | initial cond: 6.4721e-14 | stress hist: 2.6477e-05
# epoch: 3870/5000 | loss: 6.0494e-05 | initial cond: 2.5888e-15 | stress hist: 6.0494e-05
# epoch: 3880/5000 | loss: 1.5904e-05 | initial cond: 2.5888e-15 | stress hist: 1.5904e-05
# epoch: 3890/5000 | loss: 3.0825e-05 | initial cond: 1.0355e-14 | stress hist: 3.0825e-05
# epoch: 3900/5000 | loss: 3.4786e-05 | initial cond: 1.0355e-14 | stress hist: 3.4786e-05
# epoch: 3910/5000 | loss: 9.0977e-05 | initial cond: 0.0000e+00 | stress hist: 9.0977e-05
# epoch: 3920/5000 | loss: 9.9211e-04 | initial cond: 0.0000e+00 | stress hist: 9.9211e-04
# epoch: 3930/5000 | loss: 1.4454e-04 | initial cond: 2.3299e-14 | stress hist: 1.4454e-04
# epoch: 3940/5000 | loss: 1.1169e-04 | initial cond: 0.0000e+00 | stress hist: 1.1169e-04
# epoch: 3950/5000 | loss: 3.8597e-05 | initial cond: 2.5888e-15 | stress hist: 3.8597e-05
# epoch: 3960/5000 | loss: 1.6158e-05 | initial cond: 0.0000e+00 | stress hist: 1.6158e-05
# epoch: 3970/5000 | loss: 2.1070e-05 | initial cond: 2.3299e-14 | stress hist: 2.1070e-05
# epoch: 3980/5000 | loss: 1.4199e-05 | initial cond: 1.0355e-14 | stress hist: 1.4199e-05
# epoch: 3990/5000 | loss: 1.4415e-05 | initial cond: 6.4721e-14 | stress hist: 1.4415e-05
# epoch: 4000/5000 | loss: 1.3701e-05 | initial cond: 2.5888e-15 | stress hist: 1.3701e-05
# epoch: 4010/5000 | loss: 2.5678e-05 | initial cond: 2.5888e-15 | stress hist: 2.5678e-05
# epoch: 4020/5000 | loss: 2.7406e-05 | initial cond: 1.0355e-14 | stress hist: 2.7406e-05
# epoch: 4030/5000 | loss: 1.6040e-05 | initial cond: 1.0355e-14 | stress hist: 1.6040e-05
# epoch: 4040/5000 | loss: 6.7160e-05 | initial cond: 2.5888e-15 | stress hist: 6.7160e-05
# epoch: 4050/5000 | loss: 5.8043e-04 | initial cond: 0.0000e+00 | stress hist: 5.8043e-04
# epoch: 4060/5000 | loss: 1.5494e-04 | initial cond: 2.5888e-15 | stress hist: 1.5494e-04
# epoch: 4070/5000 | loss: 5.5345e-05 | initial cond: 1.0355e-14 | stress hist: 5.5345e-05
# epoch: 4080/5000 | loss: 4.1312e-05 | initial cond: 0.0000e+00 | stress hist: 4.1312e-05
# epoch: 4090/5000 | loss: 1.4777e-05 | initial cond: 2.5888e-15 | stress hist: 1.4777e-05
# epoch: 4100/5000 | loss: 1.4749e-05 | initial cond: 0.0000e+00 | stress hist: 1.4749e-05
# epoch: 4110/5000 | loss: 1.4151e-05 | initial cond: 1.0355e-14 | stress hist: 1.4151e-05
# epoch: 4120/5000 | loss: 1.2903e-05 | initial cond: 0.0000e+00 | stress hist: 1.2903e-05
# epoch: 4130/5000 | loss: 1.1949e-05 | initial cond: 2.5888e-15 | stress hist: 1.1949e-05
# epoch: 4140/5000 | loss: 4.7128e-05 | initial cond: 0.0000e+00 | stress hist: 4.7128e-05
# epoch: 4150/5000 | loss: 2.3509e-04 | initial cond: 1.0355e-14 | stress hist: 2.3509e-04
# epoch: 4160/5000 | loss: 4.7320e-05 | initial cond: 0.0000e+00 | stress hist: 4.7320e-05
# epoch: 4170/5000 | loss: 1.3179e-05 | initial cond: 2.5888e-15 | stress hist: 1.3179e-05
# epoch: 4180/5000 | loss: 1.9273e-05 | initial cond: 2.5888e-15 | stress hist: 1.9273e-05
# epoch: 4190/5000 | loss: 1.3657e-05 | initial cond: 1.0355e-14 | stress hist: 1.3657e-05
# epoch: 4200/5000 | loss: 1.4695e-05 | initial cond: 2.5888e-15 | stress hist: 1.4695e-05
# epoch: 4210/5000 | loss: 1.3993e-05 | initial cond: 1.0355e-14 | stress hist: 1.3993e-05
# epoch: 4220/5000 | loss: 4.1075e-05 | initial cond: 0.0000e+00 | stress hist: 4.1075e-05
# epoch: 4230/5000 | loss: 8.5850e-04 | initial cond: 2.5888e-15 | stress hist: 8.5850e-04
# epoch: 4240/5000 | loss: 6.4222e-04 | initial cond: 2.3299e-14 | stress hist: 6.4222e-04
# epoch: 4250/5000 | loss: 6.4346e-05 | initial cond: 0.0000e+00 | stress hist: 6.4346e-05
# epoch: 4260/5000 | loss: 8.7321e-05 | initial cond: 2.3299e-14 | stress hist: 8.7321e-05
# epoch: 4270/5000 | loss: 3.2304e-05 | initial cond: 9.3198e-14 | stress hist: 3.2304e-05
# epoch: 4280/5000 | loss: 2.1987e-05 | initial cond: 0.0000e+00 | stress hist: 2.1987e-05
# epoch: 4290/5000 | loss: 1.8400e-05 | initial cond: 2.5888e-15 | stress hist: 1.8400e-05
# epoch: 4300/5000 | loss: 1.5359e-05 | initial cond: 2.5888e-15 | stress hist: 1.5359e-05
# epoch: 4310/5000 | loss: 1.7932e-05 | initial cond: 2.3299e-14 | stress hist: 1.7932e-05
# epoch: 4320/5000 | loss: 1.5583e-05 | initial cond: 1.0355e-14 | stress hist: 1.5583e-05
# epoch: 4330/5000 | loss: 1.2588e-05 | initial cond: 0.0000e+00 | stress hist: 1.2588e-05
# epoch: 4340/5000 | loss: 1.2378e-05 | initial cond: 2.5888e-15 | stress hist: 1.2378e-05
# epoch: 4350/5000 | loss: 1.2395e-05 | initial cond: 0.0000e+00 | stress hist: 1.2395e-05
# epoch: 4360/5000 | loss: 1.3304e-05 | initial cond: 0.0000e+00 | stress hist: 1.3304e-05
# epoch: 4370/5000 | loss: 3.5898e-05 | initial cond: 0.0000e+00 | stress hist: 3.5898e-05
# epoch: 4380/5000 | loss: 4.6901e-05 | initial cond: 2.3299e-14 | stress hist: 4.6901e-05
# epoch: 4390/5000 | loss: 1.8373e-05 | initial cond: 2.5888e-15 | stress hist: 1.8373e-05
# epoch: 4400/5000 | loss: 1.1933e-05 | initial cond: 0.0000e+00 | stress hist: 1.1933e-05
# epoch: 4410/5000 | loss: 3.1871e-05 | initial cond: 2.3299e-14 | stress hist: 3.1871e-05
# epoch: 4420/5000 | loss: 2.0516e-03 | initial cond: 2.5888e-15 | stress hist: 2.0516e-03
# epoch: 4430/5000 | loss: 1.9629e-04 | initial cond: 2.3299e-14 | stress hist: 1.9629e-04
# epoch: 4440/5000 | loss: 2.0604e-05 | initial cond: 2.5888e-15 | stress hist: 2.0604e-05
# epoch: 4450/5000 | loss: 3.3600e-05 | initial cond: 2.3299e-14 | stress hist: 3.3600e-05
# epoch: 4460/5000 | loss: 2.9965e-05 | initial cond: 0.0000e+00 | stress hist: 2.9965e-05
# epoch: 4470/5000 | loss: 2.0553e-05 | initial cond: 0.0000e+00 | stress hist: 2.0553e-05
# epoch: 4480/5000 | loss: 1.4698e-05 | initial cond: 6.4721e-14 | stress hist: 1.4698e-05
# epoch: 4490/5000 | loss: 1.2696e-05 | initial cond: 2.5888e-15 | stress hist: 1.2696e-05
# epoch: 4500/5000 | loss: 1.2187e-05 | initial cond: 2.3299e-14 | stress hist: 1.2187e-05
# epoch: 4510/5000 | loss: 1.3854e-05 | initial cond: 0.0000e+00 | stress hist: 1.3854e-05
# epoch: 4520/5000 | loss: 1.2091e-05 | initial cond: 0.0000e+00 | stress hist: 1.2091e-05
# epoch: 4530/5000 | loss: 1.1605e-05 | initial cond: 2.5888e-15 | stress hist: 1.1605e-05
# epoch: 4540/5000 | loss: 1.1205e-05 | initial cond: 1.0355e-14 | stress hist: 1.1205e-05
# epoch: 4550/5000 | loss: 1.0877e-05 | initial cond: 2.3299e-14 | stress hist: 1.0877e-05
# epoch: 4560/5000 | loss: 1.0652e-05 | initial cond: 2.3299e-14 | stress hist: 1.0652e-05
# epoch: 4570/5000 | loss: 1.0467e-05 | initial cond: 1.0355e-14 | stress hist: 1.0467e-05
# epoch: 4580/5000 | loss: 1.0709e-05 | initial cond: 1.0355e-14 | stress hist: 1.0709e-05
# epoch: 4590/5000 | loss: 3.8604e-05 | initial cond: 2.5888e-15 | stress hist: 3.8604e-05
# epoch: 4600/5000 | loss: 1.3626e-03 | initial cond: 0.0000e+00 | stress hist: 1.3626e-03
# epoch: 4610/5000 | loss: 3.2352e-05 | initial cond: 2.3299e-14 | stress hist: 3.2352e-05
# epoch: 4620/5000 | loss: 1.2882e-04 | initial cond: 2.5888e-15 | stress hist: 1.2882e-04
# epoch: 4630/5000 | loss: 6.7242e-05 | initial cond: 2.5888e-15 | stress hist: 6.7242e-05
# epoch: 4640/5000 | loss: 2.7065e-05 | initial cond: 1.0355e-14 | stress hist: 2.7065e-05
# epoch: 4650/5000 | loss: 1.5040e-05 | initial cond: 1.0355e-14 | stress hist: 1.5040e-05
# epoch: 4660/5000 | loss: 1.2048e-05 | initial cond: 6.4721e-14 | stress hist: 1.2048e-05
# epoch: 4670/5000 | loss: 1.1465e-05 | initial cond: 2.5888e-15 | stress hist: 1.1465e-05
# epoch: 4680/5000 | loss: 1.1027e-05 | initial cond: 2.5888e-15 | stress hist: 1.1027e-05
# epoch: 4690/5000 | loss: 1.0653e-05 | initial cond: 0.0000e+00 | stress hist: 1.0653e-05
# epoch: 4700/5000 | loss: 1.0402e-05 | initial cond: 0.0000e+00 | stress hist: 1.0402e-05
# epoch: 4710/5000 | loss: 1.0127e-05 | initial cond: 2.5888e-15 | stress hist: 1.0127e-05
# epoch: 4720/5000 | loss: 9.9022e-06 | initial cond: 2.3299e-14 | stress hist: 9.9022e-06
# epoch: 4730/5000 | loss: 9.7073e-06 | initial cond: 2.5888e-15 | stress hist: 9.7073e-06
# epoch: 4740/5000 | loss: 9.5440e-06 | initial cond: 2.5888e-15 | stress hist: 9.5440e-06
# epoch: 4750/5000 | loss: 1.5222e-05 | initial cond: 1.0355e-14 | stress hist: 1.5222e-05
# epoch: 4760/5000 | loss: 4.2033e-04 | initial cond: 2.3299e-14 | stress hist: 4.2033e-04
# epoch: 4770/5000 | loss: 5.5931e-04 | initial cond: 1.0355e-14 | stress hist: 5.5931e-04
# epoch: 4780/5000 | loss: 2.2203e-05 | initial cond: 2.3299e-14 | stress hist: 2.2203e-05
# epoch: 4790/5000 | loss: 2.7538e-05 | initial cond: 2.5888e-15 | stress hist: 2.7538e-05
# epoch: 4800/5000 | loss: 1.7895e-05 | initial cond: 0.0000e+00 | stress hist: 1.7895e-05
# epoch: 4810/5000 | loss: 1.3594e-05 | initial cond: 2.5888e-15 | stress hist: 1.3594e-05
# epoch: 4820/5000 | loss: 1.1896e-05 | initial cond: 1.0355e-14 | stress hist: 1.1896e-05
# epoch: 4830/5000 | loss: 1.0911e-05 | initial cond: 0.0000e+00 | stress hist: 1.0911e-05
# epoch: 4840/5000 | loss: 1.0332e-05 | initial cond: 2.3299e-14 | stress hist: 1.0332e-05
# epoch: 4850/5000 | loss: 9.8552e-06 | initial cond: 2.5888e-15 | stress hist: 9.8552e-06
# epoch: 4860/5000 | loss: 9.5880e-06 | initial cond: 4.1421e-14 | stress hist: 9.5880e-06
# epoch: 4870/5000 | loss: 9.3687e-06 | initial cond: 2.3299e-14 | stress hist: 9.3687e-06
# epoch: 4880/5000 | loss: 9.1450e-06 | initial cond: 0.0000e+00 | stress hist: 9.1450e-06
# epoch: 4890/5000 | loss: 2.1053e-05 | initial cond: 1.0355e-14 | stress hist: 2.1053e-05
# epoch: 4900/5000 | loss: 6.0571e-05 | initial cond: 2.5888e-15 | stress hist: 6.0571e-05
# epoch: 4910/5000 | loss: 3.5122e-04 | initial cond: 2.5888e-15 | stress hist: 3.5122e-04
# epoch: 4920/5000 | loss: 1.6018e-05 | initial cond: 0.0000e+00 | stress hist: 1.6018e-05
# epoch: 4930/5000 | loss: 6.3522e-05 | initial cond: 2.3299e-14 | stress hist: 6.3522e-05
# epoch: 4940/5000 | loss: 2.6525e-05 | initial cond: 0.0000e+00 | stress hist: 2.6525e-05
# epoch: 4950/5000 | loss: 1.0496e-05 | initial cond: 1.0355e-14 | stress hist: 1.0496e-05
# epoch: 4960/5000 | loss: 1.2139e-05 | initial cond: 1.0355e-14 | stress hist: 1.2139e-05
# epoch: 4970/5000 | loss: 1.0299e-05 | initial cond: 2.3299e-14 | stress hist: 1.0299e-05
# epoch: 4980/5000 | loss: 9.3568e-06 | initial cond: 2.3299e-14 | stress hist: 9.3568e-06
# epoch: 4990/5000 | loss: 9.1922e-06 | initial cond: 2.5888e-15 | stress hist: 9.1922e-06

# %%
norm_pred_stress.shape,norm_stress_target.shape
# Out:
# (torch.Size([260, 2, 1]), torch.Size([260, 2, 1]))

# %%
fig, ax = plt.subplots(1, 2, dpi=150, figsize=(5, 1.25))
for i, protocol in enumerate(id_protocol_train_val):
    ax[0].plot(strain_train[:, protocol].detach().numpy(),
            stress_train[:, protocol].detach().numpy(),
            linewidth=3, alpha=0.2, color='black')
    ax[0].plot(strain_train[:,protocol].detach().numpy(),
            pred_stress[:, protocol].detach().numpy(),
            linewidth=1, color='black')
    ax[1].plot(strain_train[:,protocol].detach().numpy(),
            pred_state[:, protocol,-1].detach().numpy(),
            linewidth=1, color='black')
ax[0].set_ylabel(r'$q$ (Pa)')  # Stress variable label
ax[0].set_xlabel(r'$\varepsilon_s$ (-)')  # Strain variable label    
ax[1].set_ylabel(r'$q$ (Pa)')  # Stress variable label
ax[1].set_xlabel(r'$p$ (Pa)')  # Strain variable label   
plt.show()
